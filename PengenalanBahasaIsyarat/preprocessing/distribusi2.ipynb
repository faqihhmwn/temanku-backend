# %%
import os
from collections import Counter

dataset_dir = "../dataset_fiks/fiks/img"  # ganti sesuai path dataset kamu

class_counts = {}

for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_path):
        images = [
            f for f in os.listdir(class_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ]
        class_counts[class_name] = len(images)

# Tampilkan hasil
for cls, count in sorted(class_counts.items()):
    print(f"{cls}: {count} gambar")
# Out:
# A: 53 gambar
# B: 53 gambar
# C: 53 gambar
# D: 53 gambar
# E: 53 gambar
# F: 53 gambar
# G: 53 gambar
# H: 53 gambar
# I: 53 gambar
# J: 50 gambar
# K: 53 gambar
# L: 53 gambar
# M: 53 gambar
# N: 53 gambar
# O: 53 gambar
# P: 53 gambar
# Q: 53 gambar
# R: 53 gambar
# Rumah: 53 gambar
# S: 53 gambar
# T: 53 gambar
# U: 53 gambar
# V: 53 gambar
# W: 53 gambar
# X: 53 gambar
# Y: 53 gambar
# Z: 50 gambar
# kamu: 53 gambar
# kasih: 53 gambar
# makan: 53 gambar
# nama: 51 gambar
# saya: 53 gambar
# terima: 53 gambar
# tidur: 53 gambar
# tolong: 53 gambar

# %%
import matplotlib.pyplot as plt

classes = list(class_counts.keys())
counts = list(class_counts.values())

plt.figure(figsize=(10, 6))
bars = plt.bar(classes, counts)

plt.xticks(rotation=90)
plt.xlabel("Kelas")
plt.ylabel("Jumlah Gambar")
plt.title("Persebaran Data Gambar per Kelas (Dataset Awal)")

# 👉 Tambahkan label angka di atas bar
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        str(height),
        ha='center',
        va='bottom',
        fontsize=9
    )

plt.tight_layout()
plt.show()
